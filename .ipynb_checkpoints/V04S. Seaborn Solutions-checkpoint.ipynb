# %% [markdown]
# # V04S. Seaborn Solutions

# %% [markdown]
# #### Exercise 1: Using the dataframe below:
#
# 1) Create a jointplot to show the distribution of the data.<br/>
# 2) Change the size of the plot to make it larger.<br/>
# 3) Add a title to the plot (NB You'll have to adjust the plot down).<br/>

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
df1a = pd.DataFrame({'data1':np.arange(0,400),
                     'data2':np.random.randint(0,500,400)})
df1b = pd.DataFrame({'data1':np.arange(400,1000),
                     'data2':np.random.randint(0,1000,600)})
df1 = pd.concat([df1a,df1b])                
df1.head(5)
# Out:
#    data1  data2
# 0      0    386
# 1      1     25
# 2      2    121
# 3      3     49
# 4      4    305

# %%
chart1 = sns.jointplot(df1['data1'],df1['data2'],
                       size=8)                    # Making the chart bigger

chart1.fig.suptitle('My Jointplot!',              # The plot title
                    fontsize=16)                  # Title fontsize
plt.subplots_adjust(top=0.93)                     # Moving the chart down to make room for the title

# %% [markdown]
# #### Exercise 2: Using the Numpy Array below:
#
# 1) Plot a heatmap.<br/>
# 2) Increase the size of the heatmap.<br/>
# 3) Add values to the heatmap via annotation. <br/>
# 4) Change the colours to a <a href = "https://stanford.edu/~mwaskom/software/seaborn/tutorial/color_palettes.html">nicer palette</a>.<br/>
# 5) Set a title for the heatmap.

# %%
data = np.random.rand(10,12)
data
# Out:
# array([[ 0.20275733,  0.38817641,  0.0621325 ,  0.87709452,  0.45254277,
#          0.81223667,  0.95441242,  0.01140445,  0.30034872,  0.25327839,
#          0.13721161,  0.5817558 ],
#        [ 0.85660897,  0.10979294,  0.43758202,  0.28290242,  0.81005887,
#          0.9790819 ,  0.63060458,  0.43003939,  0.18771807,  0.24889078,
#          0.84068782,  0.94485716],
#        [ 0.80131431,  0.01120971,  0.94948323,  0.481027  ,  0.3873476 ,
#          0.19629962,  0.05063732,  0.49931267,  0.25359456,  0.4842232 ,
#          0.74765557,  0.37244656],
#        [ 0.19313618,  0.93731881,  0.36651157,  0.22179879,  0.53877949,
#          0.42871252,  0.24750535,  0.94743878,  0.69888585,  0.53100598,
#          0.55864469,  0.86745447],
#        [ 0.91215592,  0.71217726,  0.96561163,  0.49353464,  0.9627276 ,
#          0.62517063,  0.82916015,  0.64682338,  0.62260809,  0.711794  ,
#          0.88373884,  0.92231893],
#        [ 0.60034059,  0.1121419 ,  0.23584425,  0.47095447,  0.89647717,
#          0.46314663,  0.37093918,  0.38041345,  0.58375712,  0.09056054,
#          0.81861053,  0.67014201],
#        [ 0.10051588,  0.96868972,  0.6973151 ,  0.46862194,  0.59027734,
#          0.40529827,  0.9744404 ,  0.21599665,  0.75690646,  0.43035153,
#          0.36844078,  0.81383498],
#        [ 0.08010155,  0.02329881,  0.59374016,  0.74526864,  0.10725181,
#          0.72909   ,  0.11097803,  0.17875202,  0.20991204,  0.04450758,
#          0.85264602,  0.03166705],
#        [ 0.18366968,  0.21925396,  0.63592565,  0.17200396,  0.11617293,
#          0.16961176,  0.4548616 ,  0.45619882,  0.28860294,  0.52404886,
#          0.52582075,  0.82731137],
#        [ 0.82636532,  0.14132104,  0.03542131,  0.31897891,  0.39950888,
#          0.08032584,  0.40158737,  0.17652476,  0.60898228,  0.68534442,
#          0.30696763,  0.516428  ]])

# %%
chart2 = sns.heatmap(data,
                     annot=True,       # Annotating the heatmap with values
                     cmap="winter")    # Setting the palette
chart2.figure.set_size_inches(12,8)    # Setting the size of the heatmap
chart2.set_title("Winter Heatmap")     # Set the title of the heatmap
chart2                                 # Showing the heatmap
