# %% [markdown]
# # B01: Getting Started

# %% [markdown]
# This section details how to install Python via the Anaconda Installation.

# %% [markdown]
# ## Python and Anaconda

# %% [markdown]
# You'll remembed that I mentioned in the previous section that Python was extendable and the user community had developed packages and additional software to support it. An excellent example of this is Anaconda, also known as the Anaconda Installation.
#
# Many people have created some excellent packages for Python that have extended its functionality into the realm of data analysis and visualisation.
#
# Anaconda gathers 400 or so of these into a single downloadable and executable file which will automatically put everything you need on your PC to allow you to start doing the fun stuff almost immediately.

# %% [markdown]
# As I mentioned previously there are two versions of Python in use, version 2 and 3. As such there are two versions of Anaconda also, Anaconda 2 and Anaconda 3. It's very important that you download and use <strong>Anaconda 3</strong> otherwise there will be parts that do not work! The version of Anaconda that the course has been created with is version 4.3.1. Again, earlier and later versions of Anaconda may experience issues.
#
# ### Windows Installation
#
# Before installing you'll need to know if you have a <a href="http://windows.microsoft.com/en-us/windows/32-bit-and-64-bit-windows#1TC=windows-7">32 or 64 bit Windows installation</a> since you'll have to install a specific version of Anaconda:
#
# * <a href = "https://repo.continuum.io/archive/Anaconda3-4.3.1-Windows-x86.exe">Anaconda 4.3.1 Win 32 bit</a>
# * <a href = "https://repo.continuum.io/archive/Anaconda3-4.3.1-Windows-x86_64.exe">Anaconda 4.3.1 Win 64 bit</a>
#
# ### Mac Installation
#
# To install for Mac, click the link below and download the .pkg file:
#
# * <a href = "https://repo.continuum.io/archive/Anaconda3-4.3.1-MacOSX-x86_64.pkg">Anaconda 4.3.1 Mac</a>
#
# ### Linux Installation
#
# Again you'll need to know whether your <a href = "https://www.howtogeek.com/198615/how-to-check-if-your-linux-system-is-32-bit-or-64-bit/">version of Linux is 32 or 64 bit</a> and download the appropriate installer.
#
# * <a href = "https://repo.continuum.io/archive/Anaconda2-4.3.1-Linux-x86.sh">Anaconda 4.3.1 Linux 32 bit</a>
# * <a href = "https://repo.continuum.io/archive/Anaconda2-4.3.1-Linux-x86_64.sh">Anaconda 4.3.1 Linux 64 bit</a>
#
# A complete archive of all the available Anaconda installations, including Apple and Linux versions, are available from <a href = "https://repo.continuum.io/archive/index.html">this link</a>
#
# Full instructions for each operating system are available here: <a href = "https://www.continuum.io/downloads">Installation Instructions</a>

# %% [markdown]
# ## The Anaconda Navigator

# %% [markdown]
# Recently Anaconda created the Anaconda Launcher as a way to launch the various applications that come bundled with Anaconda. If you double click it, you'll see something like the following (note that this may differ depending upon your OS):
#
# <img src = "img/anaconda-launcher.png">

# %% [markdown]
# For now all we're really interested in is the Jupyter Notebook (highlighted with a red box) so select the blue Launch button to start it. Note you can also navigate to the Jupyter icon in the Anaconda directory on the start bar. This will essentially do the same thing.
#
# You will also all have a Jupyter Notebook shortcut on your windows start bar. This is a far quicker and easier way to start Jupyter!

# %% [markdown]
# ## Jupyter

# %% [markdown]
# Jupyter (aka the Jupyter notebook) is the interface that we'll be using for this course. You may also hear this referred to as 'IPython'. Note that this is the old name for Jupyter and is still used by a lot of people when referring to it.
#
# Jupyter runs through any web browser, although I'd reccomend Chrome or Firefox for best results! Note that this does not mean that your code and data are being shared with the internet! When in default mode all code and data is held and stored locally on your computer.
#
# Once you've started Jupyter a shell window will open as follows:

# %% [markdown]
# <img src = "img/terminal.png">

# %% [markdown]
# All you need to do with this window is <strong>not close it!</strong>
#
# Think of this window as the back end to the nice pretty front end that Jupyter provides - it controls something called the Python Kernal (basically an instance of Python) and all we need to do is minimise the window and it will happily run in the background. Once we're done, we can close the window using the red 'X' button as you would any other window.

# %% [markdown]
# A few seconds later, your default internet browser will start and you'll be greeted with the Jupyter landing page.
#
# Select <b>New</b> and then under Notebooks <b>Python 3</b>. This will create a blank Jupyter notebook in a new window.

# %% [markdown]
# <img src = "img/jupyter.jpg">

# %% [markdown]
# Alternatively you can open up the course notebooks saved on your desktop by clicking the home icon in the top left and then selecting 'Desktop' from the list of folders. This will then display the course notebooks.
#
# Also note that you can view these online <a href = "http://nbviewer.jupyter.org/github/Tommo565/Python-For-Analysts/tree/master/">here</a>.

# %% [markdown]
# ## Interacting with Jupyter

# %% [markdown]
# Writing code in Jupyter is also easy - simply click in a cell and type. To execute code you can use the run cell button on the toolbar above, or press Ctrl + Enter together. All your notebooks are automatically saved for you every two minutes.
#
# Note that the file will be saved in the location where you opened the notebook - this defaults to your root user directory. For the purpose of this course I reccomend that you save your notebooks in the Training folder on your desktop as this will ensure that all your material is kept together.
#
# You can access your desktop in Jupyter by clicking the home icon and then the Desktop folder:

# %% [markdown]
# <img src = "img/desktop.png">

# %% [markdown]
# From there select the Python-training folder and you should see a long list of notebooks that form the course material.
#
# If you open a Jupyter notebook whilst in this location, the resulting file will be saved there automatically, and you can rename it by clicking in the appropriate area and overwriting the default text:

# %% [markdown]
# <img src = "img/rename.png">

# %% [markdown]
# We'll be learning about Jupyter as we go, however there is a great introduction available <a href = "https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/">here</a>.

# %% [markdown]
# ## Jupyter Cells

# %% [markdown]
# Jupyter is made up of cells. Each of these cells can hold either code, markdown or 'raw' text. You can select the type of cell by selecting the appropriate drop down box on the Jupyter menu bar as follows:

# %% [markdown]
# <img src = "img/cell type.png">

# %% [markdown]
# Code is for your Python code, Markdown formatted free text, rawNB convert is unformatted text and finally heading is for headings. This helps make your Jupyter notebooks look a lot nicer and it also allows you to add pictures, explanations etc. to your code to aid presentation.
#
# You can find a cheatsheet on how to write Markdown code <a href = "https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet">here</a>.
#
# You can insert cells by selecting the <strong>Insert</strong> menu item and then selecting <b>Insert Cell Above</b> or <b>Insert Cell Below</b>.
#
# You can delete cells by clicking in the appropriate cell and selecting the <b>Edit</b> menu and then <b>Delete Cell</b>.

# %% [markdown]
# ## Executing Code

# %% [markdown]
# There are two ways to execute code in Jupyter. The first is to use the Run cell button on the menu bar as follows:

# %% [markdown]
# <img src = "img/run cell.png">

# %% [markdown]
# The second is to press <b>Shift + Enter</b> together. If you want to interrupt the execution of the code you can use the interrupt kernel button:

# %% [markdown]
# <img src = "img/interrupt.png">

# %% [markdown]
# You also have more options to restart and clear the output from the <strong>Kernel</strong> menu item in the event of a crash.

# %% [markdown]
# A few more things to note about Jupyter...
#
# * Although it operates in a web browser, it's connected to your local machine and not the internet!
# * It autosaves every few minutes
# * It saves the notebooks in the directory you were in when you created th notebook.
# * Files are saved with the extension .ipynb
# * It integrates very well with servers etc. so you can run it on a virtual machine or server (e.g. AWS)

# %% [markdown]
# ## Reference Code (aka a 'Cookbook')

# %% [markdown]
# Whilst we'll be executing all of our code in Jupyter, I'd strongly advise you to start a Cookbook file where you can save useful snippets of code to serve as a reference. If you want an example, feel free to check out my Python cookbook on <a href = "https://github.com/Tommo565/Cookbooks/blob/master/Python.py">Github</a>.
#
# As part of this course you will be provided with a .py reference file containing a list of code that we'll have executed and learned. I strongly reccomend you keep this safe and add to it over time as you learn new techniques.
#
# Just a reminder... Jupyter files are saved with the <b>.ipynb</b> extension and must be opened with Jupyter, wheras Python files are saved with the <b>.py</b> extension, however you will be able to open these in any text editor or notepad.

# %% [markdown]
# ## Further Reading

# %% [markdown]
# <a href = "https://repo.continuum.io/archive/Anaconda3-4.3.1-Windows-x86.exe">Anaconda 4.3.1 Win 32 bit Download</a><br/>
# <a href = "https://repo.continuum.io/archive/Anaconda3-4.3.1-Windows-x86_64.exe">Anaconda 4.3.1 Win 64 bit Download</a><br/>
# <a href = "https://repo.continuum.io/archive/Anaconda3-4.3.1-MacOSX-x86_64.pkg">Anaconda 4.3.1 Mac Download</a><br/>
# <a href = "https://repo.continuum.io/archive/Anaconda2-4.3.1-Linux-x86.sh">Anaconda 4.3.1 Linux 32 bit Download</a><br/>
# <a href = "https://repo.continuum.io/archive/Anaconda2-4.3.1-Linux-x86_64.sh">Anaconda 4.3.1 Linux 64 bit Download</a><br/>
# <a href = "https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/">Intro to Jupyter</a><br/>
# <a href = "https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet">Markdown Cheatsheet</a><br/>
# <a href = "https://github.com/Tommo565/Cookbooks/blob/master/Python.py">Tom's Cookbook</a><br/>
# <a href = "http://nbviewer.jupyter.org/github/Tommo565/Python-For-Analysts/tree/master/">Online Course Materials</a><br/>
